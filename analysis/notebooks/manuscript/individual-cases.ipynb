# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %load_ext lab_black

# %autoreload 2

# %%
import json

import pandas as pd
from pydash import py_

from analysis import utils
from analysis.funcs.generic import interval_str
from common_processing.resources import epigraphdb

# %%
INTERVAL = "2020-01-01/2021-12-31"
interval_fmt = interval_str(INTERVAL)
DATA_ROOT = utils.find_data_root()
data_dir = DATA_ROOT / "medrxiv_experiments" / interval_fmt / "default"
print(data_dir)
assert data_dir.exists()
# Out:
# /data/ik18445_cache/projects/evidence-retrieval-base/data/medrxiv_experiments/2020-01-01__2021-12-31/default

# %% [markdown]
# ## datasets

# %%
abstracts_file = data_dir.parent / "medrxiv_abstracts_processed.csv"
assert abstracts_file.exists()
abstracts_df = pd.read_csv(abstracts_file)
print(abstracts_df.info())
print(abstracts_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26846 entries, 0 to 26845
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   doi                               26846 non-null  object
#  1   title                             26846 non-null  object
#  2   authors                           26846 non-null  object
#  3   author_corresponding              26846 non-null  object
#  4   author_corresponding_institution  26837 non-null  object
#  5   date                              26846 non-null  object
#  6   version                           26846 non-null  int64
#  7   type                              26846 non-null  object
#  8   license                           26833 non-null  object
#  9   category                          26846 non-null  object
#  10  jatsxml                           26846 non-null  object
#  11  abstract                          26846 non-null  object
#  12  published                         9531 non-null   object
#  13  server                            26846 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 2.9+ MB
# None
#                 doi                                              title  \
# 0  10.1101/19000109  Genome-wide postnatal changes in immunity foll...
# 1  10.1101/19000653  Pain Reduction by Inducing Sensory-Motor Adapt...
# 2  10.1101/19001693  Automated interpretation of the coronary angio...
# 3  10.1101/19001719  The relationship between antihypertensive medi...
# 4  10.1101/19001495  P-hacking in clinical trials and how incentive...
#
#                                              authors author_corresponding  \
# 0  Costa, D.; Bonet, N.; Sole, A.; Gonzalez de Al...       Robert Castelo
# 1  Halicka, M.; Vitterso, A. D.; Proulx, M. J.; B...       Monika Halicka
# 2  Miyoshi, T.; Higaki, A.; Kawakami, H.; Yamaguc...       Akinori Higaki
# 3  Shaw, R. J.; Mackay, D.; Pell, J. P.; Padmanab...    Richard John Shaw
# 4                Adda, J.; Decker, C.; Ottaviani, M.      Marco Ottaviani
#
#                     author_corresponding_institution        date  version  \
# 0  Department of Experimental and Health Sciences...  2020-03-16        3
# 1                                 University of Bath  2020-01-03        2
# 2  Lady Davis Institute for Medical Research, Jew...  2020-01-08        3
# 3                              University of Glasgow  2020-01-23        3
# 4                                 Bocconi University  2020-03-27        3
#
#                   type      license                            category  \
# 0  PUBLISHAHEADOFPRINT        cc_by        genetic and genomic medicine
# 1  PUBLISHAHEADOFPRINT  cc_by_nc_nd                       pain medicine
# 2  PUBLISHAHEADOFPRINT  cc_by_nc_nd             cardiovascular medicine
# 3  PUBLISHAHEADOFPRINT        cc_no  psychiatry and clinical psychology
# 4  PUBLISHAHEADOFPRINT        cc_no                    health economics
#
#                                              jatsxml  \
# 0  https://www.medrxiv.org/content/early/2020/03/...
# 1  https://www.medrxiv.org/content/early/2020/01/...
# 2  https://www.medrxiv.org/content/early/2020/01/...
# 3  https://www.medrxiv.org/content/early/2020/01/...
# 4  https://www.medrxiv.org/content/early/2020/03/...
#
#                                             abstract  \
# 0  The fetal inflammatory response (FIR) increase...
# 1  BackgroundComplex Regional Pain Syndrome (CRPS...
# 2  BackgroundCoronary angioscopy (CAS) is a usefu...
# 3  BackgroundRecent work suggests that antihypert...
# 4  Clinical research should conform to high stand...
#
#                      published   server
# 0           10.1111/febs.15578  medrxiv
# 1    10.1186/s12883-020-1604-z  medrxiv
# 2  10.1136/openhrt-2019-001177  medrxiv
# 3    10.1017/S0033291719004094  medrxiv
# 4      10.1073/pnas.1919906117  medrxiv

# %%
combined_evidence_file = data_dir / "evidence" / "combined_score.json"
assert combined_evidence_file.exists()
with combined_evidence_file.open() as f:
    combined_evidence = json.load(f)
print(len(combined_evidence))
evidence_df = pd.DataFrame(combined_evidence)
print(evidence_df.info())
# Out:
# 413
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   doi              413 non-null    object
#  1   triple           413 non-null    object
#  2   efo_ents         413 non-null    object
#  3   umls_ents        413 non-null    object
#  4   trait_ents       413 non-null    object
#  5   subject_term     413 non-null    object
#  6   object_term      413 non-null    object
#  7   pred_term        413 non-null    object
#  8   triple_evidence  413 non-null    object
#  9   assoc_evidence   413 non-null    object
# dtypes: object(10)
# memory usage: 32.4+ KB
# None

# %% [markdown]
# # Subset

# %%
def _print_subset(df):

    for idx, _ in enumerate(df[:20]):
        url = EVIDENCE_URL.format(
            subject=_["subject_term"].replace(" ", "%20"),
            predicate=_["pred_term"],
            object=_["object_term"].replace(" ", "%20"),
        )
        print(f"#{idx} triple: {_['triple']}")
        print(f"    doi: https://doi.org/{_['doi']}")
        print(f"    evidence: {url}")
        print("Context: ----------")
        print(_["efo_ents"]["context_text"])
        print("Context: ----------")
        print("\n")
    print("\n============\n")

# %% [markdown]
# ## directional subset

# %%
EVIDENCE_URL = "http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject={subject}&predicate={predicate}&object={object}&analysis"
for pred in ["CAUSES", "TREATS", "AFFECTS", "PRODUCES"]:
    evidence_subset = [
        _
        for _ in combined_evidence
        if len([k for k, v in _["triple_evidence"].items() if len(v) > 0]) == 2
        and len([k for k, v in _["assoc_evidence"].items() if len(v) > 0]) == 4
        and _["pred_term"] == pred
    ]

    print(
        f"# Predicate {pred}; total number with full evidence types {len(evidence_subset)}\n"
    )

    _print_subset(evidence_subset)
# Out:
# # Predicate CAUSES; total number with full evidence types 8
#
# #0 triple: Valvular disease:CAUSES:Heart failure
#     doi: https://doi.org/10.1101/2020.06.04.20122010
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Valvular%20disease&predicate=CAUSES&object=Heart%20failure&analysis
# Context: ----------
# RationaleMitral valve prolapse (MVP) is a common valve disease that leads to mitral insufficiency, heart failure and sudden death.
# Context: ----------
#
#
# #1 triple: Myocardial Infarction:CAUSES:Acute myocardial infarction
#     doi: https://doi.org/10.1101/2020.07.03.20145987
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Myocardial%20Infarction&predicate=CAUSES&object=Acute%20myocardial%20infarction&analysis
# Context: ----------
# ConclusionIn addition to classic risk factors of myocardial infarction, health care systems must pay more attention to triggers that may induce an acute myocardial infarction in people with predisposing factors especially in the male sex, stressful and hand working jobs, and psychological and mental tension patients.
# Context: ----------
#
#
# #2 triple: Heart Diseases:CAUSES:Pulmonary Hypertension
#     doi: https://doi.org/10.1101/2020.09.19.20197988
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Heart%20Diseases&predicate=CAUSES&object=Pulmonary%20Hypertension&analysis
# Context: ----------
# Left heart disease was the leading cause for PH (58%), the majority suffering from valvular disease (predominantly rheumatic).
# Context: ----------
#
#
# #3 triple: Heat Stress Disorders:CAUSES:Malaise
#     doi: https://doi.org/10.1101/2020.09.22.20198820
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Heat%20Stress%20Disorders&predicate=CAUSES&object=Malaise&analysis
# Context: ----------
# MethodAn anonymous online survey was distributed to HCWs required to wear Type 1 or 2 PPE in NHS settings to evaluate the perceived impact of PPE on: (1) physical and cognitive performance; (2) heat stress and heat-related symptoms; (3) frequency of removing PPE due to discomfort caused by heat stress; and (4) general working-life and well-being.
# Context: ----------
#
#
# #4 triple: Low Back Pain:CAUSES:Chronic pain
#     doi: https://doi.org/10.1101/2021.02.18.21251719
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Low%20Back%20Pain&predicate=CAUSES&object=Chronic%20pain&analysis
# Context: ----------
# CONCLUSIONThese data provide the first evidence that low somatosensory cortex excitability in the acute stage of LBP is a cause of chronic pain.
# Context: ----------
#
#
# #5 triple: Ankylosing spondylitis:CAUSES:Arthritis
#     doi: https://doi.org/10.1101/2021.04.22.21255659
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Ankylosing%20spondylitis&predicate=CAUSES&object=Arthritis&analysis
# Context: ----------
# Ankylosing spondylitis is the second most common cause of inflammatory arthritis.
# Context: ----------
#
#
# #6 triple: Migraine Disorders:CAUSES:Dizziness
#     doi: https://doi.org/10.1101/2021.11.13.21266224
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Migraine%20Disorders&predicate=CAUSES&object=Dizziness&analysis
# Context: ----------
# INTRODUCTIONVestibular migraine is the main cause of episodic vertigo and the second most common cause of dizziness in adults.
# Context: ----------
#
#
# #7 triple: Atrial Fibrillation:CAUSES:Cardioembolic stroke
#     doi: https://doi.org/10.1101/2021.12.10.21267609
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Atrial%20Fibrillation&predicate=CAUSES&object=Cardioembolic%20stroke&analysis
# Context: ----------
# Atrial fibrillation (AF) is the main cause of CES, with which it shares heritability.
# Context: ----------
#
#
#
# ============
#
# # Predicate TREATS; total number with full evidence types 0
#
#
# ============
#
# # Predicate AFFECTS; total number with full evidence types 10
#
# #0 triple: Atrial Fibrillation:AFFECTS:Myocardial Infarction
#     doi: https://doi.org/10.1101/2020.01.29.20019521
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Atrial%20Fibrillation&predicate=AFFECTS&object=Myocardial%20Infarction&analysis
# Context: ----------
# ConclusionGenetic modelling of ivabradine recapitulates its benefits in heart failure, promotion of atrial fibrillation, and neutral effect on myocardial infarction.
# Context: ----------
#
#
# #1 triple: Obesity:AFFECTS:Diabetes
#     doi: https://doi.org/10.1101/2020.04.20.20072223
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Obesity&predicate=AFFECTS&object=Diabetes&analysis
# Context: ----------
# Risk factors for lethality in COVID-19 include early-onset diabetes, obesity, COPD, advanced age, hypertension, immunosuppression, and CKD; we observed that obesity mediates 49.5% of the effect of diabetes on COVID-19 lethality.
# Context: ----------
#
#
# #2 triple: Diabetes:AFFECTS:Asthma
#     doi: https://doi.org/10.1101/2020.08.24.20179192
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Diabetes&predicate=AFFECTS&object=Asthma&analysis
# Context: ----------
# The size of the at-risk population was stable over time comparing 2014 to 2019, despite increases in chronic liver disease and diabetes and decreases in chronic kidney disease and current asthma.
# Context: ----------
#
#
# #3 triple: Diabetes:AFFECTS:Chronic Kidney Diseases
#     doi: https://doi.org/10.1101/2020.08.24.20179192
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Diabetes&predicate=AFFECTS&object=Chronic%20Kidney%20Diseases&analysis
# Context: ----------
# The size of the at-risk population was stable over time comparing 2014 to 2019, despite increases in chronic liver disease and diabetes and decreases in chronic kidney disease and current asthma.
# Context: ----------
#
#
# #4 triple: Diabetes:AFFECTS:Obesity
#     doi: https://doi.org/10.1101/2020.09.02.20186619
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Diabetes&predicate=AFFECTS&object=Obesity&analysis
# Context: ----------
# Higher levels of risk factor prevalence among adults with overweight and obesity, in parallel with rising diabetes, highlight the importance of national prevention efforts to combat the public health impact of excess adiposity.
# Context: ----------
#
#
# #5 triple: Diabetes:AFFECTS:Parkinson Disease
#     doi: https://doi.org/10.1101/2020.11.12.20230474
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Diabetes&predicate=AFFECTS&object=Parkinson%20Disease&analysis
# Context: ----------
# Using MR we found supportive evidence for a causal effect of diabetes on PD risk (IVW OR 1.08, 95% CI 1.02-1.14; p=0.010) and some evidence of an effect on motor progression (IVW OR 1.10, 95% CI 1.01-1.20; p=0.032), but not for cognitive progression.
# Context: ----------
#
#
# #6 triple: Carotid Stenosis:AFFECTS:Cerebral Infarction
#     doi: https://doi.org/10.1101/2020.11.15.20232157
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Carotid%20Stenosis&predicate=AFFECTS&object=Cerebral%20Infarction&analysis
# Context: ----------
# Approximate 16% of patients have collateral vascular resistance greater than 5.0 and are predicted to be at high risk of cerebral ischemia or infarction with progression to severe carotid stenosis or occlusion.
# Context: ----------
#
#
# #7 triple: Carotid Stenosis:AFFECTS:Infarction
#     doi: https://doi.org/10.1101/2020.11.15.20232157
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Carotid%20Stenosis&predicate=AFFECTS&object=Infarction&analysis
# Context: ----------
# Approximate 16% of patients have collateral vascular resistance greater than 5.0 and are predicted to be at high risk of cerebral ischemia or infarction with progression to severe carotid stenosis or occlusion.
# Context: ----------
#
#
# #8 triple: Sleep:AFFECTS:Diabetes Mellitus, Non-Insulin-Dependent
#     doi: https://doi.org/10.1101/2020.12.18.20224733
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Sleep&predicate=AFFECTS&object=Diabetes%20Mellitus,%20Non-Insulin-Dependent&analysis
# Context: ----------
# C_LIO_LIMendelian randomization (MR) studies have not found evidence of a causal effect of short sleep on type 2 diabetes or glycaemic traits but have indicated an effect of insomnia on type 2 diabetes.
# Context: ----------
#
#
# #9 triple: Myocardial Infarction:AFFECTS:Coronary Circulation
#     doi: https://doi.org/10.1101/2021.03.23.21253594
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Myocardial%20Infarction&predicate=AFFECTS&object=Coronary%20Circulation&analysis
# Context: ----------
# Depending on the affected area, the corresponding symptoms appear - angina or myocardial infarction when affecting the coronary circulation; transient ischemic attack (TIA) or stroke affecting cerebral circulation; claudication or gangrene when affecting the limbs; aneurysm or dissection affecting the aorta.
# Context: ----------
#
#
#
# ============
#
# # Predicate PRODUCES; total number with full evidence types 0
#
#
# ============

# %% [markdown]
# ## undirectional subset

# %%
EVIDENCE_URL = "http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject={subject}&predicate={predicate}&object={object}&analysis"
for pred in ["ASSOCIATED_WITH", "COEXISTS_WITH", "INTERACTS_WITH"]:
    evidence_subset = [
        _
        for _ in combined_evidence
        if len([k for k, v in _["triple_evidence"].items() if len(v) > 0]) == 1
        and len([k for k, v in _["assoc_evidence"].items() if len(v) > 0]) == 2
        and _["pred_term"] == pred
    ]

    print(
        f"# Predicate {pred}; total number with full evidence types {len(evidence_subset)}\n"
    )

    _print_subset(evidence_subset)
# Out:
# # Predicate ASSOCIATED_WITH; total number with full evidence types 33
#
# #0 triple: Sleep:ASSOCIATED_WITH:Alzheimer's Disease
#     doi: https://doi.org/10.1101/2020.02.26.20027912
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Sleep&predicate=ASSOCIATED_WITH&object=Alzheimer's%20Disease&analysis
# Context: ----------
# Our goal was to assess whether genome-wide polygenic risk scores (PRS) for AD associate with sleep phenotypes in young adults, decades before typical AD symptom onset.
# Context: ----------
#
#
# #1 triple: Testosterone:ASSOCIATED_WITH:Malignant neoplasm of prostate
#     doi: https://doi.org/10.1101/2020.03.27.20044941
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Testosterone&predicate=ASSOCIATED_WITH&object=Malignant%20neoplasm%20of%20prostate&analysis
# Context: ----------
# Total testosterone was not associated with prostate cancer.
# Context: ----------
#
#
# #2 triple: C-reactive protein:ASSOCIATED_WITH:Vitamin D Deficiency
#     doi: https://doi.org/10.1101/2020.04.08.20058578
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=C-reactive%20protein&predicate=ASSOCIATED_WITH&object=Vitamin%20D%20Deficiency&analysis
# Context: ----------
# Our analysis determined a possible link between high CRP and Vit D deficiency and calculated an OR of 1.8 with 95%CI (1.2 to 2.6) among the elderly (age [&ge;] 60 yo) in low-income families and an OR of 1.9 with 95%CI (1.4 to 2.7) among the elderly (age [&ge;] 60 yo) in high-income families.
# Context: ----------
#
#
# #3 triple: Sleep:ASSOCIATED_WITH:Disease
#     doi: https://doi.org/10.1101/2020.04.11.20061887
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Sleep&predicate=ASSOCIATED_WITH&object=Disease&analysis
# Context: ----------
# N24HSWD is a circadian disorder characterized by a cyclical pattern of aberrant circadian and sleep-wake cycles that are associated with increased frequency of sleep episodes during the school/work day hours.
# Context: ----------
#
#
# #4 triple: Albumins:ASSOCIATED_WITH:Parkinson Disease
#     doi: https://doi.org/10.1101/2020.05.18.20103085
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Albumins&predicate=ASSOCIATED_WITH&object=Parkinson%20Disease&analysis
# Context: ----------
# Chronological changes in height, albumin, hemoglobin, and bicarbonate were different in PD.
# Context: ----------
#
#
# #5 triple: Hemoglobin:ASSOCIATED_WITH:Parkinson Disease
#     doi: https://doi.org/10.1101/2020.05.18.20103085
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Hemoglobin&predicate=ASSOCIATED_WITH&object=Parkinson%20Disease&analysis
# Context: ----------
# Chronological changes in height, albumin, hemoglobin, and bicarbonate were different in PD.
# Context: ----------
#
#
# #6 triple: High Density Lipoproteins:ASSOCIATED_WITH:Malignant Neoplasms
#     doi: https://doi.org/10.1101/2020.06.06.20123992
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=High%20Density%20Lipoproteins&predicate=ASSOCIATED_WITH&object=Malignant%20Neoplasms&analysis
# Context: ----------
# Dyslipidemia (adjusted odds ratio 2.164, 95% confidence interval 1.165-4.021) and decreased high-density lipoprotein (HDL, adjusted odds ratio 3.035, 95% confidence interval 1.645-5.600) were closely associated with increased risk of malignancy.
# Context: ----------
#
#
# #7 triple: Blood Pressure:ASSOCIATED_WITH:Obesity
#     doi: https://doi.org/10.1101/2020.09.13.20155234
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Blood%20Pressure&predicate=ASSOCIATED_WITH&object=Obesity&analysis
# Context: ----------
# - We further demonstrate that the causal effect of obesity on kidney health is partially mediated by blood pressure and largely independent of type 2 diabetes.
# Context: ----------
#
#
# #8 triple: Copper:ASSOCIATED_WITH:Iron deficiency anemia
#     doi: https://doi.org/10.1101/2020.09.17.20196956
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Copper&predicate=ASSOCIATED_WITH&object=Iron%20deficiency%20anemia&analysis
# Context: ----------
# ResultsGenetically predicted higher blood levels of iron and copper are both associated with lower risks of iron deficiency anemia (OR = 0.75, 95% CI:0.67-0.85, p =1.90x10-06 for iron; OR= 0.88, 95% CI: 0.78-0.98, p =0.03 for cooper), lipid metabolism disorders and its two subcategories, hyperlipidemia (OR = 0.90, 95% CI:0.85-0.96, p =6.44x10-04 for iron; OR = 0.92, 95% CI:0.87-0.98, p = 5.51x10-03 for cooper) and hypercholesterolemia (OR = 0.90, 95% CI:0.84-0.95, p = 5.34x10-04 for iron; OR = 0.93, 95% CI:0.89-0.99, p =0.02 for cooper).
# Context: ----------
#
#
# #9 triple: Iron:ASSOCIATED_WITH:Iron deficiency anemia
#     doi: https://doi.org/10.1101/2020.09.17.20196956
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Iron&predicate=ASSOCIATED_WITH&object=Iron%20deficiency%20anemia&analysis
# Context: ----------
# ResultsGenetically predicted higher blood levels of iron and copper are both associated with lower risks of iron deficiency anemia (OR = 0.75, 95% CI:0.67-0.85, p =1.90x10-06 for iron; OR= 0.88, 95% CI: 0.78-0.98, p =0.03 for cooper), lipid metabolism disorders and its two subcategories, hyperlipidemia (OR = 0.90, 95% CI:0.85-0.96, p =6.44x10-04 for iron; OR = 0.92, 95% CI:0.87-0.98, p = 5.51x10-03 for cooper) and hypercholesterolemia (OR = 0.90, 95% CI:0.84-0.95, p = 5.34x10-04 for iron; OR = 0.93, 95% CI:0.89-0.99, p =0.02 for cooper).
# Context: ----------
#
#
# #10 triple: Triglycerides:ASSOCIATED_WITH:Diabetes
#     doi: https://doi.org/10.1101/2020.11.11.20229351
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Triglycerides&predicate=ASSOCIATED_WITH&object=Diabetes&analysis
# Context: ----------
# After adjustment for multiple covariates, cholesteryl ester (CE)(22:4), lysophosphatidylcholine (LPC)(18:2), phosphatidylcholine (PC)(36:4), phosphatidylcholine-plasmalogen(34:3), and phosphatidylethanolamine (PE)(38:2) were associated with decreased risk of diabetes (HRs=0.70 to 0.82 per SD increment), while diacylglycerol(32:0), LPC(14:0), PC(38:3), PE(36:1), and triacylglycerol(50:1) were associated with increased risk of diabetes (HRs=1.26 to 1.56 per SD increment).
# Context: ----------
#
#
# #11 triple: C-reactive protein:ASSOCIATED_WITH:Depressive disorder
#     doi: https://doi.org/10.1101/2020.11.25.20238436
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=C-reactive%20protein&predicate=ASSOCIATED_WITH&object=Depressive%20disorder&analysis
# Context: ----------
# Childhood CRP was not associated with adult psychosis or depression.
# Context: ----------
#
#
# #12 triple: Pain:ASSOCIATED_WITH:Fibromyalgia
#     doi: https://doi.org/10.1101/2020.11.24.20188011
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Pain&predicate=ASSOCIATED_WITH&object=Fibromyalgia&analysis
# Context: ----------
# Our study demonstrates that mental health decline during the COVID-19 pandemic is directly related to the worsening of pain in fibromyalgia.
# Context: ----------
#
#
# #13 triple: Sleep disturbances:ASSOCIATED_WITH:Alzheimer's Disease
#     doi: https://doi.org/10.1101/2021.01.27.21250608
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Sleep%20disturbances&predicate=ASSOCIATED_WITH&object=Alzheimer's%20Disease&analysis
# Context: ----------
# High burden of tau-inclusions, but comparably milder loss of MCH neurons in AD, together with previously reported orexinergic neuronal loss may lead to a hyperexcitability of the MCH system in AD, contributing to wake-sleep disorders in AD.
# Context: ----------
#
#
# #14 triple: C-reactive protein:ASSOCIATED_WITH:Depressive disorder
#     doi: https://doi.org/10.1101/2021.02.02.21250987
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=C-reactive%20protein&predicate=ASSOCIATED_WITH&object=Depressive%20disorder&analysis
# Context: ----------
# MethodsUsing data from up to 144,890 UK Biobank cohort participants, we tested associations of circulating CRP concentrations with depression and anxiety symptom scores and probable diagnosis, including tests for linearity, disorder-specificity and sex difference.
# Context: ----------
#
#
# #15 triple: Blood Pressure:ASSOCIATED_WITH:Hypertensive disease
#     doi: https://doi.org/10.1101/2021.02.02.21251036
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Blood%20Pressure&predicate=ASSOCIATED_WITH&object=Hypertensive%20disease&analysis
# Context: ----------
# Older age, physical-inactivity, higher BMI and newly diagnosed hypertension were significantly associated with uncontrolled blood-pressure.
# Context: ----------
#
#
# #16 triple: Glucose:ASSOCIATED_WITH:Obesity
#     doi: https://doi.org/10.1101/2021.02.15.21251768
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Glucose&predicate=ASSOCIATED_WITH&object=Obesity&analysis
# Context: ----------
# ResultsAssociation of BMI with fasting glucose was greater in those without obesity than in those with obesity.
# Context: ----------
#
#
# #17 triple: C-reactive protein:ASSOCIATED_WITH:Arteriosclerosis
#     doi: https://doi.org/10.1101/2021.02.19.21252052
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=C-reactive%20protein&predicate=ASSOCIATED_WITH&object=Arteriosclerosis&analysis
# Context: ----------
# It was found out that high levels of IL-6 and CRP are associated with progressing atherosclerosis of carotid arteries and its cerebral complications.
# Context: ----------
#
#
# #18 triple: Sleep:ASSOCIATED_WITH:Alzheimer's Disease
#     doi: https://doi.org/10.1101/2021.03.08.21253133
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Sleep&predicate=ASSOCIATED_WITH&object=Alzheimer's%20Disease&analysis
# Context: ----------
# The association of SS with AD was, however, lost after the exclusion of overlapping UKB samples.
# Context: ----------
#
#
# #19 triple: Lipoproteins:ASSOCIATED_WITH:Disease
#     doi: https://doi.org/10.1101/2021.03.26.21254411
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Lipoproteins&predicate=ASSOCIATED_WITH&object=Disease&analysis
# Context: ----------
# ConclusionsPlasma levels of TLP associate with active TB disease in HIV positive subjects and can be used as an indicator for TB detection in children.
# Context: ----------
#
#
#
# ============
#
# # Predicate COEXISTS_WITH; total number with full evidence types 92
#
# #0 triple: Mental disorders:COEXISTS_WITH:Diabetes
#     doi: https://doi.org/10.1101/19006189
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Mental%20disorders&predicate=COEXISTS_WITH&object=Diabetes&analysis
# Context: ----------
# ConclusionsOutcomes suggest psychiatric disorders are more important comorbidities of long-term cognitive change than diabetes and cardiovascular disease, and demographic factors.
# Context: ----------
#
#
# #1 triple: Heart Diseases:COEXISTS_WITH:Neoplasm Metastasis
#     doi: https://doi.org/10.1101/2020.01.03.19015602
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Heart%20Diseases&predicate=COEXISTS_WITH&object=Neoplasm%20Metastasis&analysis
# Context: ----------
# BackgroundLeft ventricular non-compaction (LVNC) is a condition characterised by trabeculations in the myocardial wall and is the subject of considerable conjecture as to whether it represents a distinct pathology or a secondary phenotype associated with other cardiac diseases, particularly cardiomyopathies.
# Context: ----------
#
#
# #2 triple: Mild cognitive disorder:COEXISTS_WITH:Depressive disorder
#     doi: https://doi.org/10.1101/2020.01.03.20016345
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Mild%20cognitive%20disorder&predicate=COEXISTS_WITH&object=Depressive%20disorder&analysis
# Context: ----------
# Depression, diabetes and low educational attainment were associated with MCI without memory impairment.
# Context: ----------
#
#
# #3 triple: Mild cognitive disorder:COEXISTS_WITH:Diabetes
#     doi: https://doi.org/10.1101/2020.01.03.20016345
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Mild%20cognitive%20disorder&predicate=COEXISTS_WITH&object=Diabetes&analysis
# Context: ----------
# Depression, diabetes and low educational attainment were associated with MCI without memory impairment.
# Context: ----------
#
#
# #4 triple: Diabetes Mellitus:COEXISTS_WITH:Obesity
#     doi: https://doi.org/10.1101/2020.01.08.20016980
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Diabetes%20Mellitus&predicate=COEXISTS_WITH&object=Obesity&analysis
# Context: ----------
# BC cases with clinical stage T II and positive LN as well as tumor histologic grade III, presence of obesity, pre-diabetic events, DM or IR were associated with CD295 rs6700986 mutant homozygous (CC) and heterozygous (CT) genotype and ITLN1 rs952804 mutant heterozygous genotype (CT) (P [&le;] 0.05).
# Context: ----------
#
#
# #5 triple: Malignant Neoplasms:COEXISTS_WITH:Malignant neoplasm of lung
#     doi: https://doi.org/10.1101/2020.01.08.20016915
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Malignant%20Neoplasms&predicate=COEXISTS_WITH&object=Malignant%20neoplasm%20of%20lung&analysis
# Context: ----------
# ConclusionDouble checkpoint inhibitor PD-1/PD-L1 combined with CTLA-4 antibody has synergistic anti-cancer activity and improved ORR and PFS in lung cancer.
# Context: ----------
#
#
# #6 triple: Triglycerides:COEXISTS_WITH:Very low density lipoprotein
#     doi: https://doi.org/10.1101/2020.01.15.19015206
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Triglycerides&predicate=COEXISTS_WITH&object=Very%20low%20density%20lipoprotein&analysis
# Context: ----------
# Larger sex differences at older ages were most pronounced for triglycerides in VLDL - e.g. male levels were 0.19 standard deviation (SD) units (95% CI=0.12, 0.26) higher at age 18y, 0.50 SD (95% CI=0.42, 0.57) higher at age 25y, and 0.62 SD (95% CI=0.55, 0.68) higher at age 50y.
# Context: ----------
#
#
# #7 triple: Schizophrenia:COEXISTS_WITH:Unipolar Depression
#     doi: https://doi.org/10.1101/2020.01.15.20017699
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Schizophrenia&predicate=COEXISTS_WITH&object=Unipolar%20Depression&analysis
# Context: ----------
# ConclusionsA higher genetic liability to SCZ may reduce responsiveness to pharmacological treatment in MDD.
# Context: ----------
#
#
# #8 triple: Depressive disorder:COEXISTS_WITH:Unipolar Depression
#     doi: https://doi.org/10.1101/2020.01.14.20017384
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Depressive%20disorder&predicate=COEXISTS_WITH&object=Unipolar%20Depression&analysis
# Context: ----------
# ConclusionsTaken together, these findings indicate that PSD is associated with microstructural characteristics of the reward system, similar to those observed in major depressive disorder without stroke.
# Context: ----------
#
#
# #9 triple: Early gastric cancer:COEXISTS_WITH:Infection caused by Helicobacter pylori
#     doi: https://doi.org/10.1101/2020.04.04.20052852
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Early%20gastric%20cancer&predicate=COEXISTS_WITH&object=Infection%20caused%20by%20Helicobacter%20pylori&analysis
# Context: ----------
# EGCC with oesophageal invasion (n=22), compared to EGCC without (n=48), showed no significant differences in the H. pylori infection rate and oesophageal columnar, intestinal, or pancreatic metaplasia, except for a higher percentage of the former in size > 2 cm and tubular differentiation.
# Context: ----------
#
#
# #10 triple: Diabetes:COEXISTS_WITH:Disease
#     doi: https://doi.org/10.1101/2020.04.08.20058040
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Diabetes&predicate=COEXISTS_WITH&object=Disease&analysis
# Context: ----------
# BackgroundConcomitance with diabetes is associated with high mortality in critical conditions.
# Context: ----------
#
#
# #11 triple: Hepatic impairment:COEXISTS_WITH:Disease
#     doi: https://doi.org/10.1101/2020.04.24.20074179
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Hepatic%20impairment&predicate=COEXISTS_WITH&object=Disease&analysis
# Context: ----------
# ConclusionsIn this meta-analysis, we comprehensively described three patterns of liver impairment related to COVID-19, namely hepatocellular injury, cholestasis, and hepatocellular disfunction, according to COVID-19 severity.
# Context: ----------
#
#
# #12 triple: Hepatic impairment:COEXISTS_WITH:Disease
#     doi: https://doi.org/10.1101/2020.04.26.20080580
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Hepatic%20impairment&predicate=COEXISTS_WITH&object=Disease&analysis
# Context: ----------
# ConclusionsIn this meta-analysis, according to the main clinical outcome of COVID-19, we comprehensively described three patterns of liver impairment related to COVID-19, hepatocellular injury, cholestasis, and hepatocellular disfunction.
# Context: ----------
#
#
# #13 triple: Depressive disorder:COEXISTS_WITH:Mixed anxiety and depressive disorder
#     doi: https://doi.org/10.1101/2020.04.30.20086926
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Depressive%20disorder&predicate=COEXISTS_WITH&object=Mixed%20anxiety%20and%20depressive%20disorder&analysis
# Context: ----------
# Therefore, this study was conducted to assess prevalence of depression, anxiety and depression-anxiety comorbidity, and associated factors during the COVID-19 lockdown in Nepal.
# Context: ----------
#
#
# #14 triple: Parkinson Disease:COEXISTS_WITH:Huntington Disease
#     doi: https://doi.org/10.1101/2020.05.07.20084343
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Parkinson%20Disease&predicate=COEXISTS_WITH&object=Huntington%20Disease&analysis
# Context: ----------
# We used a new method in PD, following a similar approach in Huntingtons disease, where we combined multiple assessments using a principal components analysis to derive scores for composite, motor, and cognitive progression.
# Context: ----------
#
#
# #15 triple: Chronic disease:COEXISTS_WITH:Obesity
#     doi: https://doi.org/10.1101/2020.05.11.20097873
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Chronic%20disease&predicate=COEXISTS_WITH&object=Obesity&analysis
# Context: ----------
# Obesity is associated with many chronic illnesses, such as hypertension, coronary artery disease, dyslipidaemia, metabolic liver disease, renal and urological diseases, sleep apnoea, type 2 diabetes, osteoarthritis, psychiatric comorbidity, gastro-oesophageal reflux disease, and some cancers.
# Context: ----------
#
#
# #16 triple: Malignant Neoplasms:COEXISTS_WITH:Disease
#     doi: https://doi.org/10.1101/2020.05.12.20098996
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Malignant%20Neoplasms&predicate=COEXISTS_WITH&object=Disease&analysis
# Context: ----------
# The value of an additional life year was borrowed from new, innovative oncological drugs, as cancer reflects a condition with a similar morbidity and mortality burden in the general population in the short term as COVID-19.
# Context: ----------
#
#
# #17 triple: Acute hypoxemic respiratory failure:COEXISTS_WITH:Disease
#     doi: https://doi.org/10.1101/2020.05.24.20111013
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Acute%20hypoxemic%20respiratory%20failure&predicate=COEXISTS_WITH&object=Disease&analysis
# Context: ----------
# IntroductionNoninvasive respiratory support (NRS) such as noninvasive ventilation (NIV) and high flow nasal therapy (HFNT) have been used in the treatment of acute hypoxemic respiratory failure (AHRF) related to the coronavirus disease (COVID-19) and other viral infections.
# Context: ----------
#
#
# #18 triple: Hypertensive disease:COEXISTS_WITH:Diabetes
#     doi: https://doi.org/10.1101/2020.06.01.20086025
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Hypertensive%20disease&predicate=COEXISTS_WITH&object=Diabetes&analysis
# Context: ----------
# The incidence of hypertension, coronary heart disease, chronic obstructive pulmonary disease, and diabetes comorbidities increased with age (trend test, P <.0001, P = 0.0003, P <.0001, and P <.0001 respectively).
# Context: ----------
#
#
# #19 triple: Malaise:COEXISTS_WITH:Disease
#     doi: https://doi.org/10.1101/2020.06.08.20125229
#     evidence: http://ieu-db-interface.epi.bris.ac.uk:8626/triple?subject=Malaise&predicate=COEXISTS_WITH&object=Disease&analysis
# Context: ----------
# Increased reports of spontaneous discomfort, bleeding, swelling and discomfort during brushing were observed in presence of disease.
# Context: ----------
#
#
#
# ============
#
# # Predicate INTERACTS_WITH; total number with full evidence types 0
#
#
# ============

# %% [markdown]
# # term frequency

# %%
evidence_subset = [
    _
    for _ in combined_evidence
    if len([k for k, v in _["triple_evidence"].items() if len(v) > 0]) == 2
    and len([k for k, v in _["assoc_evidence"].items() if len(v) > 0]) == 4
    and _["pred_term"] == "CAUSES"
]
subset = (
    py_.chain(evidence_subset)
    .map(lambda _: [_["subject_term"], _["object_term"]])
    .flatten()
    .value()
)
print(subset)
# Out:
# ['Valvular disease', 'Heart failure', 'Myocardial Infarction', 'Acute myocardial infarction', 'Heart Diseases', 'Pulmonary Hypertension', 'Heat Stress Disorders', 'Malaise', 'Low Back Pain', 'Chronic pain', 'Ankylosing spondylitis', 'Arthritis', 'Migraine Disorders', 'Dizziness', 'Atrial Fibrillation', 'Cardioembolic stroke']

# %%
from typing import List


def make_word_freq(terms: List[str]) -> pd.DataFrame():
    word_freq = {}
    tokens = (
        py_.chain(terms)
        .map(lambda term: [_.strip().lower() for _ in term.split(",")])
        .flatten()
        .value()
    )
    for token in tokens:
        if token not in word_freq.keys():
            word_freq[token] = 1
        else:
            word_freq[token] += 1
    word_freq_df = (
        pd.Series(word_freq)
        .sort_values(ascending=False)
        .to_frame(name="count")
        .assign(total_num_tokens=len(tokens))
    )
    return word_freq_df


df = make_word_freq(terms=subset)
print(df[:10])
# Out:
#                              count  total_num_tokens
# valvular disease                 1                16
# heart failure                    1                16
# myocardial infarction            1                16
# acute myocardial infarction      1                16
# heart diseases                   1                16
# pulmonary hypertension           1                16
# heat stress disorders            1                16
# malaise                          1                16
# low back pain                    1                16
# chronic pain                     1                16

# %% [markdown]
# ## cases with full evidence groups

# %%
pred_groups = [
    {
        "preds": ["CAUSES", "TREATS", "AFFECTS", "PRODUCES"],
        "num_triple_evidence": 2,
        "num_assoc_evidence": 4,
    },
    {
        "preds": ["ASSOCIATED_WITH", "COEXISTS_WITH", "INTERACTS_WITH"],
        "num_triple_evidence": 1,
        "num_assoc_evidence": 2,
    },
]

for pred_group in pred_groups:
    print(f"preds {pred_group['preds']}")
    evidence_subset = [
        _
        for _ in combined_evidence
        if len([k for k, v in _["triple_evidence"].items() if len(v) > 0])
        == pred_group["num_triple_evidence"]
        and len([k for k, v in _["assoc_evidence"].items() if len(v) > 0])
        == pred_group["num_assoc_evidence"]
        and _["pred_term"] in pred_group["preds"]
    ]
    terms = (
        py_.chain(evidence_subset)
        .map(lambda _: [_["subject_term"], _["object_term"]])
        .flatten()
        .value()
    )
    word_freq_df = make_word_freq(terms=terms)
    print(word_freq_df[:20])
# Out:
# preds ['CAUSES', 'TREATS', 'AFFECTS', 'PRODUCES']
#                         count  total_num_tokens
# diabetes                    5                37
# myocardial infarction       3                37
# atrial fibrillation         2                37
# carotid stenosis            2                37
# obesity                     2                37
# valvular disease            1                37
# sleep                       1                37
# dizziness                   1                37
# migraine disorders          1                37
# arthritis                   1                37
# ankylosing spondylitis      1                37
# coronary circulation        1                37
# chronic pain                1                37
# low back pain               1                37
# non-insulin-dependent       1                37
# diabetes mellitus           1                37
# infarction                  1                37
# heart failure               1                37
# cerebral infarction         1                37
# parkinson disease           1                37
# preds ['ASSOCIATED_WITH', 'COEXISTS_WITH', 'INTERACTS_WITH']
#                               count  total_num_tokens
# disease                          34               256
# obesity                          12               256
# depressive disorder              11               256
# parkinson disease                 9               256
# diabetes                          9               256
# schizophrenia                     8               256
# malignant neoplasms               7               256
# c-reactive protein                7               256
# alzheimer's disease               6               256
# chronic disease                   5               256
# diabetes mellitus                 5               256
# fatigue                           4               256
# sleep                             4               256
# mental disorders                  3               256
# hypertensive disease              3               256
# enthesitis-related arthritis      3               256
# atrial fibrillation               3               256
# chronic kidney diseases           3               256
# pain                              3               256
# triglycerides                     3               256

# %% [markdown]
# ## cases with at least "supporting"

# %%
for pred_group in pred_groups:
    print(f"preds {pred_group['preds']}")
    evidence_subset = [
        _
        for _ in combined_evidence
        if "supporting" in _["triple_evidence"].keys()
        and len(_["triple_evidence"]["supporting"]) > 0
        and "supporting" in _["assoc_evidence"].keys()
        and len(_["assoc_evidence"]["supporting"]) > 0
        and _["pred_term"] in pred_group["preds"]
    ]
    terms = (
        py_.chain(evidence_subset)
        .map(lambda _: [_["subject_term"], _["object_term"]])
        .flatten()
        .value()
    )
    word_freq_df = make_word_freq(terms=terms)
    print(word_freq_df[:20])
# Out:
# preds ['CAUSES', 'TREATS', 'AFFECTS', 'PRODUCES']
#                          count  total_num_tokens
# diabetes mellitus            9               134
# obesity                      8               134
# diabetes                     8               134
# non-insulin-dependent        8               134
# disease                      7               134
# parkinson disease            4               134
# blood glucose                4               134
# glucose                      3               134
# myocardial infarction        3               134
# behavior                     3               134
# depressive disorder          3               134
# chronic kidney diseases      3               134
# gout                         2               134
# carotid stenosis             2               134
# asthma                       2               134
# atrial fibrillation          2               134
# alzheimer's disease          2               134
# heart failure                2               134
# depressive symptoms          1               134
# arthritis                    1               134
# preds ['ASSOCIATED_WITH', 'COEXISTS_WITH', 'INTERACTS_WITH']
#                               count  total_num_tokens
# disease                          34               256
# obesity                          12               256
# depressive disorder              11               256
# parkinson disease                 9               256
# diabetes                          9               256
# schizophrenia                     8               256
# malignant neoplasms               7               256
# c-reactive protein                7               256
# alzheimer's disease               6               256
# chronic disease                   5               256
# diabetes mellitus                 5               256
# fatigue                           4               256
# sleep                             4               256
# mental disorders                  3               256
# hypertensive disease              3               256
# enthesitis-related arthritis      3               256
# atrial fibrillation               3               256
# chronic kidney diseases           3               256
# pain                              3               256
# triglycerides                     3               256
