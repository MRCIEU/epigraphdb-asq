# %% [markdown]
# # Cases

# %% [markdown]
# # Init

# %%
import networkx as nx
from pyvis.network import Network

# %% [markdown]
# # Cases meta overview

# %%
from typing import List


def make_word_freq(terms: List[str]) -> pd.DataFrame:
    word_freq = {}
    corpus = (
        py_.chain(terms).map(lambda e: {"term": e, "token": e.strip().lower()}).value()
    )
    tokens = py_.chain(corpus).map(lambda e: e["token"]).uniq().value()
    for item in corpus:
        token = item["token"]
        term = item["term"]
        if token not in word_freq.keys():
            word_freq[token] = {
                "token": token,
                "terms": {term},
                "count": 1,
            }
        else:
            word_freq[token]["count"] += 1
            word_freq[token]["terms"] = word_freq[token]["terms"].union({term})
    word_freq_df = (
        pd.DataFrame.from_dict(word_freq, orient="index")
        .sort_values(by=["count"], ascending=False)
        .assign(total_num_tokens=len(tokens))
        .assign(term=lambda df: df["terms"].apply(lambda e: list(e)))
        .explode("term")
    )
    return word_freq_df


df = make_word_freq(terms=["Apple", "Apple ", "apple", "Orange"])
df
# Out:
#          token                   terms  count  total_num_tokens    term
# apple    apple  {Apple , Apple, apple}      3                 2  Apple
# apple    apple  {Apple , Apple, apple}      3                 2   Apple
# apple    apple  {Apple , Apple, apple}      3                 2   apple
# orange  orange                {Orange}      1                 2  Orange

# %%
# terms count all cases
terms_count_all = (
    py_.chain(combined_evidence)
    .map(lambda e: [e["subject_term"], e["object_term"]])
    .flatten()
    .thru(lambda o: make_word_freq(o))
    .value()
)
terms_count_all.head(20)
# Out:
#                                                                              token  \
# disease                                                                    disease
# obesity                                                                    obesity
# depressive disorder                                            depressive disorder
# coronavirus infections                                      coronavirus infections
# diabetes                                                                  diabetes
# malignant neoplasms                                            malignant neoplasms
# diabetes mellitus, non-insulin-dependent  diabetes mellitus, non-insulin-dependent
# hypertensive disease                                          hypertensive disease
# parkinson disease                                                parkinson disease
# schizophrenia                                                        schizophrenia
# alzheimer's disease                                            alzheimer's disease
# mental disorders                                                  mental disorders
# c-reactive protein                                              c-reactive protein
# atrial fibrillation                                            atrial fibrillation
# chronic kidney diseases                                    chronic kidney diseases
# iron                                                                          iron
# neoplasms                                                                neoplasms
# age                                                                            age
# antihypertensive agents                                    antihypertensive agents
# malignant neoplasm of breast                          malignant neoplasm of breast
#
#                                                                                terms  \
# disease                                                                    {Disease}
# obesity                                                                    {Obesity}
# depressive disorder                                            {Depressive disorder}
# coronavirus infections                                      {Coronavirus Infections}
# diabetes                                                                  {Diabetes}
# malignant neoplasms                                            {Malignant Neoplasms}
# diabetes mellitus, non-insulin-dependent  {Diabetes Mellitus, Non-Insulin-Dependent}
# hypertensive disease                                          {Hypertensive disease}
# parkinson disease                                                {Parkinson Disease}
# schizophrenia                                                        {Schizophrenia}
# alzheimer's disease                                            {Alzheimer's Disease}
# mental disorders                                                  {Mental disorders}
# c-reactive protein                                              {C-reactive protein}
# atrial fibrillation                                            {Atrial Fibrillation}
# chronic kidney diseases                                    {Chronic Kidney Diseases}
# iron                                                                          {Iron}
# neoplasms                                                                {Neoplasms}
# age                                                                            {Age}
# antihypertensive agents                                    {Antihypertensive Agents}
# malignant neoplasm of breast                          {Malignant neoplasm of breast}
#
#                                           count  total_num_tokens  \
# disease                                      77               275
# obesity                                      30               275
# depressive disorder                          26               275
# coronavirus infections                       21               275
# diabetes                                     20               275
# malignant neoplasms                          19               275
# diabetes mellitus, non-insulin-dependent     15               275
# hypertensive disease                         13               275
# parkinson disease                            13               275
# schizophrenia                                11               275
# alzheimer's disease                          10               275
# mental disorders                             10               275
# c-reactive protein                           10               275
# atrial fibrillation                           9               275
# chronic kidney diseases                       9               275
# iron                                          8               275
# neoplasms                                     7               275
# age                                           7               275
# antihypertensive agents                       7               275
# malignant neoplasm of breast                  6               275
#
#                                                                               term
# disease                                                                    Disease
# obesity                                                                    Obesity
# depressive disorder                                            Depressive disorder
# coronavirus infections                                      Coronavirus Infections
# diabetes                                                                  Diabetes
# malignant neoplasms                                            Malignant Neoplasms
# diabetes mellitus, non-insulin-dependent  Diabetes Mellitus, Non-Insulin-Dependent
# hypertensive disease                                          Hypertensive disease
# parkinson disease                                                Parkinson Disease
# schizophrenia                                                        Schizophrenia
# alzheimer's disease                                            Alzheimer's Disease
# mental disorders                                                  Mental disorders
# c-reactive protein                                              C-reactive protein
# atrial fibrillation                                            Atrial Fibrillation
# chronic kidney diseases                                    Chronic Kidney Diseases
# iron                                                                          Iron
# neoplasms                                                                Neoplasms
# age                                                                            Age
# antihypertensive agents                                    Antihypertensive Agents
# malignant neoplasm of breast                          Malignant neoplasm of breast

# %%
# term count, with both triple support and evidence support
def _has_supporting_evidence(e):
    triple = (
        "supporting" in e["triple_evidence"].keys()
        and len(e["triple_evidence"]["supporting"]) > 0
    )
    assoc = (
        "supporting" in e["assoc_evidence"].keys()
        and len(e["assoc_evidence"]["supporting"]) > 0
    )
    return triple and assoc


terms_count_support = (
    py_.chain(combined_evidence)
    .filter(_has_supporting_evidence)
    .map(lambda e: [e["subject_term"], e["object_term"]])
    .flatten()
    .thru(lambda o: make_word_freq(o))
    .value()
)
terms_count_support.head(20)
# Out:
#                                                                              token  \
# disease                                                                    disease
# obesity                                                                    obesity
# diabetes                                                                  diabetes
# depressive disorder                                            depressive disorder
# parkinson disease                                                parkinson disease
# diabetes mellitus, non-insulin-dependent  diabetes mellitus, non-insulin-dependent
# alzheimer's disease                                            alzheimer's disease
# schizophrenia                                                        schizophrenia
# c-reactive protein                                              c-reactive protein
# malignant neoplasms                                            malignant neoplasms
# chronic kidney diseases                                    chronic kidney diseases
# atrial fibrillation                                            atrial fibrillation
# sleep                                                                        sleep
# chronic disease                                                    chronic disease
# fatigue                                                                    fatigue
# pain                                                                          pain
# glucose                                                                    glucose
# blood glucose                                                        blood glucose
# hypertensive disease                                          hypertensive disease
# mental disorders                                                  mental disorders
#
#                                                                                terms  \
# disease                                                                    {Disease}
# obesity                                                                    {Obesity}
# diabetes                                                                  {Diabetes}
# depressive disorder                                            {Depressive disorder}
# parkinson disease                                                {Parkinson Disease}
# diabetes mellitus, non-insulin-dependent  {Diabetes Mellitus, Non-Insulin-Dependent}
# alzheimer's disease                                            {Alzheimer's Disease}
# schizophrenia                                                        {Schizophrenia}
# c-reactive protein                                              {C-reactive protein}
# malignant neoplasms                                            {Malignant Neoplasms}
# chronic kidney diseases                                    {Chronic Kidney Diseases}
# atrial fibrillation                                            {Atrial Fibrillation}
# sleep                                                                        {Sleep}
# chronic disease                                                    {Chronic disease}
# fatigue                                                                    {Fatigue}
# pain                                                                          {Pain}
# glucose                                                                    {Glucose}
# blood glucose                                                        {Blood Glucose}
# hypertensive disease                                          {Hypertensive disease}
# mental disorders                                                  {Mental disorders}
#
#                                           count  total_num_tokens  \
# disease                                      41               144
# obesity                                      20               144
# diabetes                                     17               144
# depressive disorder                          14               144
# parkinson disease                            13               144
# diabetes mellitus, non-insulin-dependent     10               144
# alzheimer's disease                           8               144
# schizophrenia                                 8               144
# c-reactive protein                            7               144
# malignant neoplasms                           7               144
# chronic kidney diseases                       6               144
# atrial fibrillation                           5               144
# sleep                                         5               144
# chronic disease                               5               144
# fatigue                                       5               144
# pain                                          4               144
# glucose                                       4               144
# blood glucose                                 4               144
# hypertensive disease                          4               144
# mental disorders                              4               144
#
#                                                                               term
# disease                                                                    Disease
# obesity                                                                    Obesity
# diabetes                                                                  Diabetes
# depressive disorder                                            Depressive disorder
# parkinson disease                                                Parkinson Disease
# diabetes mellitus, non-insulin-dependent  Diabetes Mellitus, Non-Insulin-Dependent
# alzheimer's disease                                            Alzheimer's Disease
# schizophrenia                                                        Schizophrenia
# c-reactive protein                                              C-reactive protein
# malignant neoplasms                                            Malignant Neoplasms
# chronic kidney diseases                                    Chronic Kidney Diseases
# atrial fibrillation                                            Atrial Fibrillation
# sleep                                                                        Sleep
# chronic disease                                                    Chronic disease
# fatigue                                                                    Fatigue
# pain                                                                          Pain
# glucose                                                                    Glucose
# blood glucose                                                        Blood Glucose
# hypertensive disease                                          Hypertensive disease
# mental disorders                                                  Mental disorders

# %%
terms_count_init = (
    py_.chain(triples)
    .filter(lambda e: len(e["triples"]) > 0)
    .map(lambda e: [[_["sub_term"], _["obj_term"]] for _ in e["triples"]])
    .flatten_deep()
    .thru(lambda o: make_word_freq(o))
    .value()
)
terms_count_init
# Out:
#                  token         terms  count  total_num_tokens        term
# patients      patients    {Patients}   1896              5564    Patients
# disease        disease     {Disease}    715              5564     Disease
# vaccines      vaccines    {Vaccines}    328              5564    Vaccines
# persons        persons     {Persons}    315              5564     Persons
# symptoms      symptoms    {Symptoms}    279              5564    Symptoms
# ...                ...           ...    ...               ...         ...
# galr1 gene  galr1 gene  {GALR1 gene}      1              5564  GALR1 gene
# or2b3 gene  or2b3 gene  {OR2B3 gene}      1              5564  OR2B3 gene
# tead4 gene  tead4 gene  {TEAD4 gene}      1              5564  TEAD4 gene
# tsr3 gene    tsr3 gene   {TSR3 gene}      1              5564   TSR3 gene
# hiv 2 p26    hiv 2 p26   {HIV 2 p26}      1              5564   HIV 2 p26
#
# [5564 rows x 5 columns]

# %%
terms_count_assoc_support = (
    py_.chain(combined_evidence)
    .filter(
        lambda e: "supporting" in e["assoc_evidence"].keys()
        and len(e["assoc_evidence"]["supporting"]) > 0
    )
    .map(lambda e: [e["subject_term"], e["object_term"]])
    .flatten()
    .thru(lambda o: make_word_freq(o))
    .value()
)
terms_count_triple_support = (
    py_.chain(combined_evidence)
    .filter(
        lambda e: "supporting" in e["triple_evidence"].keys()
        and len(e["triple_evidence"]["supporting"]) > 0
    )
    .map(lambda e: [e["subject_term"], e["object_term"]])
    .flatten()
    .thru(lambda o: make_word_freq(o))
    .value()
)

terms_count_tbl = (
    terms_count_support[["term", "count"]]
    .rename(columns={"count": "count_support"})
    .merge(
        terms_count_all[["term", "count"]].rename(columns={"count": "count_any"}),
        on=["term"],
    )
    .merge(
        terms_count_triple_support[["term", "count"]].rename(
            columns={"count": "count_triple_support"}
        ),
        on=["term"],
    )
    .merge(
        terms_count_assoc_support[["term", "count"]].rename(
            columns={"count": "count_assoc_support"}
        ),
        on=["term"],
    )
    .merge(
        terms_count_init[["term", "count"]].rename(columns={"count": "count_init"}),
        on=["term"],
    )
    .sort_values(by=["count_support"], ascending=False)
    .reset_index(drop=True)
)
terms_count_tbl.head(20)
# Out:
#                                         term  count_support  count_any  \
# 0                                    Disease             41         77
# 1                                    Obesity             20         30
# 2                                   Diabetes             17         20
# 3                        Depressive disorder             14         26
# 4                          Parkinson Disease             13         13
# 5   Diabetes Mellitus, Non-Insulin-Dependent             10         15
# 6                        Alzheimer's Disease              8         10
# 7                              Schizophrenia              8         11
# 8                         C-reactive protein              7         10
# 9                        Malignant Neoplasms              7         19
# 10                   Chronic Kidney Diseases              6          9
# 11                           Chronic disease              5          6
# 12                                   Fatigue              5          6
# 13                                     Sleep              5          6
# 14                       Atrial Fibrillation              5          9
# 15                                      Pain              4          6
# 16                                   Glucose              4          6
# 17                             Blood Glucose              4          5
# 18                      Hypertensive disease              4         13
# 19                          Mental disorders              4         10
#
#     count_triple_support  count_assoc_support  count_init
# 0                     74                   44         715
# 1                     25                   25         125
# 2                     19                   18          87
# 3                     20                   16         100
# 4                     13                   13         111
# 5                     12                   12          84
# 6                     10                    8         111
# 7                     11                    8          32
# 8                      7                    9          24
# 9                      8                   15         100
# 10                     9                    6          35
# 11                     6                    5          44
# 12                     5                    6          25
# 13                     5                    6          21
# 14                     6                    6          57
# 15                     4                    6          30
# 16                     5                    4          20
# 17                     5                    4          15
# 18                    12                    4          90
# 19                     8                    4          42

# %%
output_file = analysis_assets_dir / "case_term_count.tex"
terms_count_tbl.style.to_latex(output_file)

# %% [markdown]
# # Individual

# %%
PRIMARY_TERM = "Obesity"
# PRIMARY_TERM = "Depressive disorder"

# %%
def _make_score(e):
    res = sum([_["evidence_score"] for _ in e])
    return res


def _extract_data(e):
    triple_supporting = (
        _make_score(e["triple_evidence"]["supporting"])
        if "supporting" in e["triple_evidence"].keys()
        else 0
    )
    assoc_supporting = (
        _make_score(e["assoc_evidence"]["supporting"])
        if "supporting" in e["assoc_evidence"].keys()
        else 0
    )
    res = {
        "doi": e["doi"],
        "triple": e["triple"],
        "subject_term": e["subject_term"],
        "object_term": e["object_term"],
        "pred_term": e["pred_term"],
        "pred_group": epigraphdb.PRED_DIRECTIONAL_MAPPING[e["pred_term"]],
        "triple_supporting": triple_supporting,
        "assoc_supporting": assoc_supporting,
        "score_supporting": triple_supporting + assoc_supporting,
    }
    return res


def make_case(primary_term, combined_evidence):
    _is_term_first = lambda e, primary_term: (
        e["subject_term"] == primary_term or e["object_term"] == primary_term
    )
    _is_term_second = lambda e, terms: (
        e["subject_term"] in terms and e["object_term"] in terms
    )

    valid_terms = (
        py_.chain(combined_evidence)
        .filter(_is_term_first)
        .filter(lambda e: _is_term_first(e, primary_term))
        .map(lambda e: [e["subject_term"], e["object_term"]])
        .flatten()
        .uniq()
        .thru(lambda o: [_ for _ in o if _ != primary_term])
        .value()
    )

    case_df = (
        py_.chain(combined_evidence)
        .filter(
            lambda e: _is_term_first(e, primary_term) or _is_term_second(e, valid_terms)
        )
        .map(_extract_data)
        .thru(lambda o: pd.DataFrame(o))
        .value()
    )
    return case_df


case_df = make_case(primary_term=PRIMARY_TERM, combined_evidence=combined_evidence)
print(case_df.info())
case_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   doi                30 non-null     object
#  1   triple             30 non-null     object
#  2   subject_term       30 non-null     object
#  3   object_term        30 non-null     object
#  4   pred_term          30 non-null     object
#  5   pred_group         30 non-null     object
#  6   triple_supporting  30 non-null     float64
#  7   assoc_supporting   30 non-null     float64
#  8   score_supporting   30 non-null     float64
# dtypes: float64(3), object(6)
# memory usage: 2.2+ KB
# None
#                             doi  \
# 0   10.1101/2020.01.08.20016980
# 1   10.1101/2020.03.19.20031138
# 2   10.1101/2020.03.19.20031138
# 3   10.1101/2020.04.02.20049031
# 4   10.1101/2020.04.20.20016337
# 5   10.1101/2020.04.20.20072223
# 6   10.1101/2020.05.11.20097873
# 7   10.1101/2020.06.22.20137182
# 8   10.1101/2020.08.20.20176214
# 9   10.1101/2020.09.02.20186619
# 10  10.1101/2020.09.13.20155234
# 11  10.1101/2020.09.23.20200360
# 12  10.1101/2020.09.23.20200360
# 13  10.1101/2021.02.04.21249454
# 14  10.1101/2021.02.15.21251768
# 15  10.1101/2021.03.26.21254420
# 16  10.1101/2021.03.26.21254420
# 17  10.1101/2021.04.19.21255222
# 18  10.1101/2021.05.07.21256703
# 19  10.1101/2021.05.14.21257204
# 20  10.1101/2021.05.14.21257204
# 21  10.1101/2021.06.01.21257781
# 22  10.1101/2021.08.01.21261455
# 23  10.1101/2021.08.25.21262627
# 24  10.1101/2021.09.28.21264201
# 25  10.1101/2021.10.05.21264556
# 26  10.1101/2021.10.06.21264610
# 27  10.1101/2021.10.25.21265464
# 28  10.1101/2021.11.04.21265933
# 29  10.1101/2021.12.08.21267440
#
#                                                triple  \
# 0             Diabetes Mellitus:COEXISTS_WITH:Obesity
# 1                Obesity:AFFECTS:Colorectal Carcinoma
# 2          Colorectal Carcinoma:COEXISTS_WITH:Obesity
# 3      Obesity:AFFECTS:Malignant neoplasm of prostate
# 4                Hypertensive disease:AFFECTS:Obesity
# 5                            Obesity:AFFECTS:Diabetes
# 6               Chronic disease:COEXISTS_WITH:Obesity
# 7               Chronic disease:COEXISTS_WITH:Obesity
# 8                   Obesity:COEXISTS_WITH:Fatty Liver
# 9                            Diabetes:AFFECTS:Obesity
# 10             Blood Pressure:ASSOCIATED_WITH:Obesity
# 11                       Obesity:CAUSES:Heart failure
# 12                Heart failure:COEXISTS_WITH:Obesity
# 13                Obesity:COEXISTS_WITH:Sleep Latency
# 14                    Glucose:ASSOCIATED_WITH:Obesity
# 15                                Obesity:CAUSES:Gout
# 16                               Obesity:AFFECTS:Gout
# 17                  Obesity:AFFECTS:Pediatric Obesity
# 18                    Insulin:ASSOCIATED_WITH:Obesity
# 19            Obesity:COEXISTS_WITH:Diabetes Mellitus
# 20                     Diabetes:COEXISTS_WITH:Obesity
# 21                             Obesity:CAUSES:Disease
# 22  Malignant neoplasm of endometrium:AFFECTS:Obesity
# 23                        Age:ASSOCIATED_WITH:Obesity
# 24  Obesity:COEXISTS_WITH:Non-alcoholic Fatty Live...
# 25  Obesity:COEXISTS_WITH:Malignant neoplasm of pr...
# 26                Obesity:AFFECTS:Depressive disorder
# 27  Obesity:COEXISTS_WITH:Latent Autoimmune Diabet...
# 28               Obesity:AFFECTS:daily energy intakes
# 29                         Obesity:CAUSES:Fatty Liver
#
#                          subject_term                           object_term  \
# 0                   Diabetes Mellitus                               Obesity
# 1                             Obesity                  Colorectal Carcinoma
# 2                Colorectal Carcinoma                               Obesity
# 3                             Obesity        Malignant neoplasm of prostate
# 4                Hypertensive disease                               Obesity
# 5                             Obesity                              Diabetes
# 6                     Chronic disease                               Obesity
# 7                     Chronic disease                               Obesity
# 8                             Obesity                           Fatty Liver
# 9                            Diabetes                               Obesity
# 10                     Blood Pressure                               Obesity
# 11                            Obesity                         Heart failure
# 12                      Heart failure                               Obesity
# 13                            Obesity                         Sleep Latency
# 14                            Glucose                               Obesity
# 15                            Obesity                                  Gout
# 16                            Obesity                                  Gout
# 17                            Obesity                     Pediatric Obesity
# 18                            Insulin                               Obesity
# 19                            Obesity                     Diabetes Mellitus
# 20                           Diabetes                               Obesity
# 21                            Obesity                               Disease
# 22  Malignant neoplasm of endometrium                               Obesity
# 23                                Age                               Obesity
# 24                            Obesity     Non-alcoholic Fatty Liver Disease
# 25                            Obesity        Malignant neoplasm of prostate
# 26                            Obesity                   Depressive disorder
# 27                            Obesity  Latent Autoimmune Diabetes in Adults
# 28                            Obesity                  daily energy intakes
# 29                            Obesity                           Fatty Liver
#
#           pred_term     pred_group  triple_supporting  assoc_supporting  \
# 0     COEXISTS_WITH  undirectional          18.799260         10.794803
# 1           AFFECTS    directional           0.000000         11.951282
# 2     COEXISTS_WITH  undirectional           0.000000          8.321694
# 3           AFFECTS    directional           0.680812          1.219657
# 4           AFFECTS    directional           5.346700          0.000000
# 5           AFFECTS    directional          15.905478         18.528986
# 6     COEXISTS_WITH  undirectional          17.796887          1.041043
# 7     COEXISTS_WITH  undirectional          17.796887          1.041043
# 8     COEXISTS_WITH  undirectional          17.349626          0.000000
# 9           AFFECTS    directional          14.666161          3.976320
# 10  ASSOCIATED_WITH  undirectional           0.912577         24.166675
# 11           CAUSES    directional          12.799016          5.106927
# 12    COEXISTS_WITH  undirectional          22.921366          6.752879
# 13    COEXISTS_WITH  undirectional           2.018191          1.027197
# 14  ASSOCIATED_WITH  undirectional           4.531363          4.078378
# 15           CAUSES    directional           3.479211          1.119082
# 16          AFFECTS    directional           3.065752          1.119082
# 17          AFFECTS    directional           9.346902          1.065829
# 18  ASSOCIATED_WITH  undirectional          12.920510          2.181423
# 19    COEXISTS_WITH  undirectional          19.078315         10.794803
# 20    COEXISTS_WITH  undirectional          25.376104         30.932436
# 21           CAUSES    directional           6.947711          0.000000
# 22          AFFECTS    directional           0.000000          2.236322
# 23  ASSOCIATED_WITH  undirectional           0.000000         12.136559
# 24    COEXISTS_WITH  undirectional          29.686373          0.000000
# 25    COEXISTS_WITH  undirectional           0.680812          2.386676
# 26          AFFECTS    directional           2.306068          2.277105
# 27    COEXISTS_WITH  undirectional           3.729075          9.576150
# 28          AFFECTS    directional           0.000000          5.463621
# 29           CAUSES    directional           8.964703          0.000000
#
#     score_supporting
# 0          29.594063
# 1          11.951282
# 2           8.321694
# 3           1.900469
# 4           5.346700
# 5          34.434464
# 6          18.837930
# 7          18.837930
# 8          17.349626
# 9          18.642481
# 10         25.079252
# 11         17.905943
# 12         29.674245
# 13          3.045388
# 14          8.609740
# 15          4.598293
# 16          4.184834
# 17         10.412731
# 18         15.101933
# 19         29.873118
# 20         56.308540
# 21          6.947711
# 22          2.236322
# 23         12.136559
# 24         29.686373
# 25          3.067488
# 26          4.583173
# 27         13.305225
# 28          5.463621
# 29          8.964703

# %% [markdown]
# ## network plot, theme specific

# %%
obesity_theme_terms = [
    "Obesity",
    "Diabetes",
    "Diabetes Mellitus, Non-Insulin-Dependent",
    "Chronic Kidney Diseases",
]
mental_theme_terms = [
    "Depressive disorder",
    "Parkinson Disease",
    "Alzheimer's Disease",
    "Schizophrenia",
]

# %%
def make_theme_df(terms: List[str]):
    res = (
        pd.concat(
            [
                make_case(primary_term=_, combined_evidence=combined_evidence).assign(
                    primary_term=_
                )
                for _ in terms
            ]
        )
        .reset_index(drop=True)[
            [
                "subject_term",
                "object_term",
                "primary_term",
                "score_supporting",
            ]
        ]
        .rename(columns={"score_supporting": "value"})
        .groupby(["subject_term", "object_term", "primary_term"])
        .sum()
        .reset_index(drop=False)
    )
    return res


obesity_theme_df = make_theme_df(terms=obesity_theme_terms)
mental_theme_df = make_theme_df(terms=mental_theme_terms)
obesity_theme_df
# Out:
#                subject_term                               object_term  \
# 0                       Age  Diabetes Mellitus, Non-Insulin-Dependent
# 1                       Age                                   Obesity
# 2               Albuminuria                                  Diabetes
# 3   Antihypertensive Agents                                  Diabetes
# 4             Blood Glucose                   Chronic Kidney Diseases
# ..                      ...                                       ...
# 58        Parkinson Disease  Diabetes Mellitus, Non-Insulin-Dependent
# 59                    Sleep  Diabetes Mellitus, Non-Insulin-Dependent
# 60       Sleep disturbances  Diabetes Mellitus, Non-Insulin-Dependent
# 61            Triglycerides                                  Diabetes
# 62                     Zinc  Diabetes Mellitus, Non-Insulin-Dependent
#
#                                 primary_term      value
# 0   Diabetes Mellitus, Non-Insulin-Dependent   2.435558
# 1                                    Obesity  12.136559
# 2                                   Diabetes  18.127536
# 3                                   Diabetes  43.673428
# 4                    Chronic Kidney Diseases   4.217776
# ..                                       ...        ...
# 58  Diabetes Mellitus, Non-Insulin-Dependent  21.993378
# 59  Diabetes Mellitus, Non-Insulin-Dependent   9.179310
# 60  Diabetes Mellitus, Non-Insulin-Dependent   0.000000
# 61                                  Diabetes  75.793859
# 62  Diabetes Mellitus, Non-Insulin-Dependent   5.771405
#
# [63 rows x 4 columns]

# %%
def make_network(theme_df, primary_terms):

    nodes_df = (
        py_.chain(theme_df.to_dict(orient="records"))
        .map(lambda e: [e["subject_term"], e["object_term"]])
        .flatten()
        .uniq()
        .thru(
            lambda o: (
                pd.Series(o)
                .to_frame(name="term")
                .merge(
                    terms_count_tbl[["term", "count_support"]], on=["term"], how="left"
                )
                .fillna(1)
            )
        )
        .value()
        .rename(columns={"term": "node", "count_support": "value"})
    )
    edges_df = theme_df.rename(
        columns={"subject_term": "source", "object_term": "target"}
    )[["source", "target", "value"]]

    nt = Network("768", "1024")

    for idx, _ in nodes_df.iterrows():
        color = "red" if _["node"] in primary_terms else "lightblue"
        nt.add_node(n_id=_["node"], label=_["node"], value=_["value"], color=color)

    for idx, _ in edges_df.iterrows():
        nt.add_edge(source=_["source"], to=_["target"], value=_["value"], color="grey")

    return nt


nt = make_network(obesity_theme_df, obesity_theme_terms)
nt.show("nt_obesity.html")

# %%
nt = make_network(mental_theme_df, mental_theme_terms)
nt.show("nt_mental.html")
