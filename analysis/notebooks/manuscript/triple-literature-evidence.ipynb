# %%
# %load_ext autoreload
# %load_ext lab_black

# %autoreload 2

# %%
import json

import requests
import pandas as pd

from analysis import utils

# %%
output_dir = utils.find_analysis_artifacts_dir()
print(output_dir)
# Out:
# /data/ik18445_cache/projects/evidence-retrieval-base/manuscript/assets/artifacts

# %% [markdown]
# # Triple count

# %%
query = """
MATCH
    (sub:LiteratureTerm)-[r:SEMMEDDB_SUB]-
    (triple:LiteratureTriple)-
    [r1:SEMMEDDB_OBJ]-(obj:LiteratureTerm)
WHERE
    triple.predicate IN [
        "INTERACTS_WITH", "COEXISTS_WITH",
        "ASSOCIATED_WITH", "CAUSES", "TREATS",
        "PRODUCES", "AFFECTS"
    ]
RETURN
    sub.type as sub_type,
    triple.predicate as pred,
    obj.type as obj_type,
    count(*) as num_ents
ORDER BY num_ents DESC LIMIT 50
"""
payload = {"query": query}
r = requests.post("https://api.epigraphdb.org/cypher", json=payload)
if not r.ok:
    print(r.text)

# %%
data = r.json()["results"]
df = pd.json_normalize(data)
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sub_type  50 non-null     object
#  1   pred      50 non-null     object
#  2   obj_type  50 non-null     object
#  3   num_ents  50 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 1.7+ KB
# None
#        sub_type             pred      obj_type  num_ents
# 0  [aapp, gngm]   INTERACTS_WITH  [aapp, gngm]    393759
# 1  [aapp, gngm]    COEXISTS_WITH  [aapp, gngm]    224098
# 2  [aapp, gngm]  ASSOCIATED_WITH        [dsyn]    188961
# 3        [dsyn]    COEXISTS_WITH        [dsyn]    150166
# 4        [dsyn]           CAUSES        [dsyn]     85231

# %%
triple_count_file = output_dir / "triple-category-count.json"
with triple_count_file.open("w") as f:
    json.dump(df.to_dict(orient="records"), f)

# %%
with triple_count_file.open() as f:
    triple_count_df = pd.DataFrame(json.load(f))
triple_count_df
# Out:
#                     sub_type             pred                  obj_type  \
# 0               [aapp, gngm]   INTERACTS_WITH              [aapp, gngm]
# 1               [aapp, gngm]    COEXISTS_WITH              [aapp, gngm]
# 2               [aapp, gngm]  ASSOCIATED_WITH                    [dsyn]
# 3                     [dsyn]    COEXISTS_WITH                    [dsyn]
# 4                     [dsyn]           CAUSES                    [dsyn]
# 5               [orch, phsu]           TREATS                    [dsyn]
# 6               [aapp, gngm]   INTERACTS_WITH        [aapp, gngm, enzy]
# 7               [aapp, gngm]         PRODUCES              [aapp, gngm]
# 8         [aapp, gngm, enzy]   INTERACTS_WITH              [aapp, gngm]
# 9               [aapp, gngm]           CAUSES                    [dsyn]
# 10                    [phsu]           TREATS                    [dsyn]
# 11              [orch, phsu]   INTERACTS_WITH              [aapp, gngm]
# 12        [aapp, gngm, phsu]   INTERACTS_WITH              [aapp, gngm]
# 13              [aapp, gngm]   INTERACTS_WITH        [aapp, gngm, phsu]
# 14              [aapp, gngm]          AFFECTS                    [dsyn]
# 15              [aapp, gngm]   INTERACTS_WITH              [orch, phsu]
# 16        [aapp, gngm, enzy]    COEXISTS_WITH              [aapp, gngm]
# 17              [aapp, gngm]    COEXISTS_WITH        [aapp, gngm, enzy]
# 18        [aapp, gngm, phsu]    COEXISTS_WITH              [aapp, gngm]
# 19        [aapp, gngm, phsu]  ASSOCIATED_WITH                    [dsyn]
# 20                    [dsyn]          AFFECTS                    [dsyn]
# 21        [aapp, gngm, enzy]  ASSOCIATED_WITH                    [dsyn]
# 22              [aapp, gngm]    COEXISTS_WITH        [aapp, gngm, phsu]
# 23              [orch, phsu]   INTERACTS_WITH              [orch, phsu]
# 24        [aapp, gngm, phsu]           TREATS                    [dsyn]
# 25              [orch, phsu]    COEXISTS_WITH              [orch, phsu]
# 26                    [gngm]   INTERACTS_WITH              [aapp, gngm]
# 27              [orch, phsu]    COEXISTS_WITH              [aapp, gngm]
# 28              [orch, phsu]           CAUSES                    [dsyn]
# 29              [aapp, gngm]    COEXISTS_WITH              [orch, phsu]
# 30                    [orch]   INTERACTS_WITH              [aapp, gngm]
# 31              [aapp, gngm]   INTERACTS_WITH                    [phsu]
# 32              [orch, phsu]          AFFECTS                    [dsyn]
# 33              [aapp, gngm]   INTERACTS_WITH                    [orch]
# 34                    [phsu]   INTERACTS_WITH              [aapp, gngm]
# 35        [aapp, gngm, enzy]   INTERACTS_WITH        [aapp, gngm, enzy]
# 36              [aapp, gngm]   INTERACTS_WITH  [aapp, gngm, phsu, enzy]
# 37              [aapp, gngm]   INTERACTS_WITH                    [gngm]
# 38              [aapp, gngm]         PRODUCES        [aapp, gngm, phsu]
# 39              [orch, phsu]   INTERACTS_WITH        [aapp, gngm, enzy]
# 40  [aapp, gngm, phsu, enzy]   INTERACTS_WITH              [aapp, gngm]
# 41                    [phsu]   INTERACTS_WITH              [orch, phsu]
# 42              [orch, phsu]   INTERACTS_WITH                    [phsu]
# 43        [aapp, gngm, enzy]   INTERACTS_WITH              [orch, phsu]
# 44                    [orch]    COEXISTS_WITH              [aapp, gngm]
# 45        [aapp, gngm, phsu]         PRODUCES              [aapp, gngm]
# 46              [aapp, gngm]   INTERACTS_WITH  [aapp, gngm, phsu, horm]
# 47                    [orch]    COEXISTS_WITH                    [orch]
# 48              [aapp, gngm]         PRODUCES        [aapp, gngm, enzy]
# 49        [aapp, gngm, enzy]         PRODUCES              [aapp, gngm]
#
#     num_ents
# 0     393759
# 1     224098
# 2     188961
# 3     150166
# 4      85231
# 5      82263
# 6      72194
# 7      69691
# 8      66742
# 9      49178
# 10     47416
# 11     41085
# 12     40310
# 13     37926
# 14     37243
# 15     36017
# 16     32877
# 17     31103
# 18     29459
# 19     29425
# 20     29167
# 21     28862
# 22     26038
# 23     25150
# 24     20354
# 25     19721
# 26     19634
# 27     19208
# 28     19064
# 29     18400
# 30     18381
# 31     17063
# 32     17038
# 33     16904
# 34     15535
# 35     15067
# 36     14439
# 37     12718
# 38     12706
# 39     12525
# 40     12172
# 41     11710
# 42     11644
# 43     11492
# 44     10741
# 45     10388
# 46      9912
# 47      9655
# 48      9624
# 49      9520

# %% [markdown]
# # Literature count

# %%
query = """
MATCH
    (sub:LiteratureTerm)-[r:SEMMEDDB_SUB]-
    (triple:LiteratureTriple)-
    [r1:SEMMEDDB_OBJ]-(obj:LiteratureTerm)
WHERE
    triple.predicate IN [
        "INTERACTS_WITH", "COEXISTS_WITH",
        "ASSOCIATED_WITH", "CAUSES", "TREATS",
        "PRODUCES", "AFFECTS"
    ]
WITH
  sub, triple, obj
MATCH
  (triple)-[r:SEMMEDDB_TO_LIT]->(lit:Literature)
RETURN
    sub.type as sub_type,
    triple.predicate as pred,
    obj.type as obj_type,
    count(*) as num_ents
ORDER BY num_ents DESC LIMIT 50
"""
payload = {"query": query}
r = requests.post("https://api.epigraphdb.org/cypher", json=payload)
if not r.ok:
    print(r.text)
data = r.json()["results"]
df = pd.json_normalize(data)
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sub_type  50 non-null     object
#  1   pred      50 non-null     object
#  2   obj_type  50 non-null     object
#  3   num_ents  50 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 1.7+ KB
# None
#                     sub_type             pred                  obj_type  \
# 0               [aapp, gngm]   INTERACTS_WITH              [aapp, gngm]
# 1               [aapp, gngm]  ASSOCIATED_WITH                    [dsyn]
# 2                     [dsyn]    COEXISTS_WITH                    [dsyn]
# 3               [aapp, gngm]    COEXISTS_WITH              [aapp, gngm]
# 4               [orch, phsu]           TREATS                    [dsyn]
# 5                     [phsu]           TREATS                    [dsyn]
# 6                     [dsyn]           CAUSES                    [dsyn]
# 7               [aapp, gngm]   INTERACTS_WITH        [aapp, gngm, enzy]
# 8         [aapp, gngm, enzy]   INTERACTS_WITH              [aapp, gngm]
# 9               [aapp, gngm]         PRODUCES              [aapp, gngm]
# 10              [aapp, gngm]           CAUSES                    [dsyn]
# 11        [aapp, gngm, phsu]  ASSOCIATED_WITH                    [dsyn]
# 12        [aapp, gngm, phsu]           TREATS                    [dsyn]
# 13        [aapp, gngm, phsu]   INTERACTS_WITH              [aapp, gngm]
# 14              [aapp, gngm]   INTERACTS_WITH        [aapp, gngm, phsu]
# 15              [orch, phsu]   INTERACTS_WITH              [aapp, gngm]
# 16        [aapp, gngm, enzy]  ASSOCIATED_WITH                    [dsyn]
# 17                    [dsyn]          AFFECTS                    [dsyn]
# 18              [aapp, gngm]          AFFECTS                    [dsyn]
# 19              [aapp, gngm]   INTERACTS_WITH              [orch, phsu]
# 20        [aapp, gngm, phsu]    COEXISTS_WITH              [aapp, gngm]
# 21        [aapp, gngm, enzy]   INTERACTS_WITH        [aapp, gngm, enzy]
# 22              [aapp, gngm]    COEXISTS_WITH        [aapp, gngm, phsu]
# 23              [orch, phsu]           CAUSES                    [dsyn]
# 24        [aapp, gngm, enzy]    COEXISTS_WITH              [aapp, gngm]
# 25              [aapp, gngm]    COEXISTS_WITH        [aapp, gngm, enzy]
# 26              [orch, phsu]   INTERACTS_WITH              [orch, phsu]
# 27              [aapp, gngm]   INTERACTS_WITH                    [phsu]
# 28  [aapp, gngm, phsu, horm]           TREATS                    [dsyn]
# 29                    [phsu]   INTERACTS_WITH              [aapp, gngm]
# 30              [orch, phsu]    COEXISTS_WITH              [orch, phsu]
# 31              [aapp, gngm]   INTERACTS_WITH  [aapp, gngm, phsu, enzy]
# 32                    [phsu]   INTERACTS_WITH              [orch, phsu]
# 33              [orch, phsu]   INTERACTS_WITH                    [phsu]
# 34              [aapp, gngm]         PRODUCES        [aapp, gngm, phsu]
# 35  [aapp, gngm, phsu, horm]  ASSOCIATED_WITH                    [dsyn]
# 36              [orch, phsu]          AFFECTS                    [dsyn]
# 37                    [orch]   INTERACTS_WITH              [aapp, gngm]
# 38              [orch, phsu]    COEXISTS_WITH              [aapp, gngm]
# 39        [aapp, gngm, phsu]           CAUSES                    [dsyn]
# 40              [aapp, gngm]   INTERACTS_WITH                    [orch]
# 41  [aapp, gngm, phsu, enzy]   INTERACTS_WITH              [aapp, gngm]
# 42              [aapp, gngm]   INTERACTS_WITH  [aapp, gngm, phsu, horm]
# 43              [aapp, gngm]    COEXISTS_WITH              [orch, phsu]
# 44        [aapp, gngm, phsu]         PRODUCES              [aapp, gngm]
# 45              [orch, phsu]    COEXISTS_WITH                    [phsu]
# 46                    [gngm]   INTERACTS_WITH              [aapp, gngm]
# 47              [orch, phsu]   INTERACTS_WITH        [aapp, gngm, enzy]
# 48  [aapp, gngm, phsu, horm]   INTERACTS_WITH              [aapp, gngm]
# 49              [orch, phsu]          AFFECTS                    [clna]
#
#     num_ents
# 0     673470
# 1     423727
# 2     385349
# 3     332834
# 4     274589
# 5     238636
# 6     222462
# 7     140836
# 8     133378
# 9     106862
# 10    100681
# 11     86176
# 12     82956
# 13     79428
# 14     74484
# 15     64266
# 16     61964
# 17     58753
# 18     57928
# 19     56558
# 20     51281
# 21     47899
# 22     47248
# 23     46666
# 24     46329
# 25     44175
# 26     40245
# 27     37782
# 28     36119
# 29     33394
# 30     32510
# 31     29794
# 32     28492
# 33     27357
# 34     26122
# 35     25262
# 36     25202
# 37     25195
# 38     24654
# 39     24472
# 40     24244
# 41     24184
# 42     23124
# 43     22826
# 44     22719
# 45     21932
# 46     21901
# 47     21381
# 48     20398
# 49     20397

# %%
literature_count_file = output_dir / "literature-category-count.json"
with literature_count_file.open("w") as f:
    json.dump(df.to_dict(orient="records"), f)

# %%
with literature_count_file.open() as f:
    literature_count_df = pd.DataFrame(json.load(f))
literature_count_df
# Out:
#                     sub_type             pred                  obj_type  \
# 0               [aapp, gngm]   INTERACTS_WITH              [aapp, gngm]
# 1               [aapp, gngm]  ASSOCIATED_WITH                    [dsyn]
# 2                     [dsyn]    COEXISTS_WITH                    [dsyn]
# 3               [aapp, gngm]    COEXISTS_WITH              [aapp, gngm]
# 4               [orch, phsu]           TREATS                    [dsyn]
# 5                     [phsu]           TREATS                    [dsyn]
# 6                     [dsyn]           CAUSES                    [dsyn]
# 7               [aapp, gngm]   INTERACTS_WITH        [aapp, gngm, enzy]
# 8         [aapp, gngm, enzy]   INTERACTS_WITH              [aapp, gngm]
# 9               [aapp, gngm]         PRODUCES              [aapp, gngm]
# 10              [aapp, gngm]           CAUSES                    [dsyn]
# 11        [aapp, gngm, phsu]  ASSOCIATED_WITH                    [dsyn]
# 12        [aapp, gngm, phsu]           TREATS                    [dsyn]
# 13        [aapp, gngm, phsu]   INTERACTS_WITH              [aapp, gngm]
# 14              [aapp, gngm]   INTERACTS_WITH        [aapp, gngm, phsu]
# 15              [orch, phsu]   INTERACTS_WITH              [aapp, gngm]
# 16        [aapp, gngm, enzy]  ASSOCIATED_WITH                    [dsyn]
# 17                    [dsyn]          AFFECTS                    [dsyn]
# 18              [aapp, gngm]          AFFECTS                    [dsyn]
# 19              [aapp, gngm]   INTERACTS_WITH              [orch, phsu]
# 20        [aapp, gngm, phsu]    COEXISTS_WITH              [aapp, gngm]
# 21        [aapp, gngm, enzy]   INTERACTS_WITH        [aapp, gngm, enzy]
# 22              [aapp, gngm]    COEXISTS_WITH        [aapp, gngm, phsu]
# 23              [orch, phsu]           CAUSES                    [dsyn]
# 24        [aapp, gngm, enzy]    COEXISTS_WITH              [aapp, gngm]
# 25              [aapp, gngm]    COEXISTS_WITH        [aapp, gngm, enzy]
# 26              [orch, phsu]   INTERACTS_WITH              [orch, phsu]
# 27              [aapp, gngm]   INTERACTS_WITH                    [phsu]
# 28  [aapp, gngm, phsu, horm]           TREATS                    [dsyn]
# 29                    [phsu]   INTERACTS_WITH              [aapp, gngm]
# 30              [orch, phsu]    COEXISTS_WITH              [orch, phsu]
# 31              [aapp, gngm]   INTERACTS_WITH  [aapp, gngm, phsu, enzy]
# 32                    [phsu]   INTERACTS_WITH              [orch, phsu]
# 33              [orch, phsu]   INTERACTS_WITH                    [phsu]
# 34              [aapp, gngm]         PRODUCES        [aapp, gngm, phsu]
# 35  [aapp, gngm, phsu, horm]  ASSOCIATED_WITH                    [dsyn]
# 36              [orch, phsu]          AFFECTS                    [dsyn]
# 37                    [orch]   INTERACTS_WITH              [aapp, gngm]
# 38              [orch, phsu]    COEXISTS_WITH              [aapp, gngm]
# 39        [aapp, gngm, phsu]           CAUSES                    [dsyn]
# 40              [aapp, gngm]   INTERACTS_WITH                    [orch]
# 41  [aapp, gngm, phsu, enzy]   INTERACTS_WITH              [aapp, gngm]
# 42              [aapp, gngm]   INTERACTS_WITH  [aapp, gngm, phsu, horm]
# 43              [aapp, gngm]    COEXISTS_WITH              [orch, phsu]
# 44        [aapp, gngm, phsu]         PRODUCES              [aapp, gngm]
# 45              [orch, phsu]    COEXISTS_WITH                    [phsu]
# 46                    [gngm]   INTERACTS_WITH              [aapp, gngm]
# 47              [orch, phsu]   INTERACTS_WITH        [aapp, gngm, enzy]
# 48  [aapp, gngm, phsu, horm]   INTERACTS_WITH              [aapp, gngm]
# 49              [orch, phsu]          AFFECTS                    [clna]
#
#     num_ents
# 0     673470
# 1     423727
# 2     385349
# 3     332834
# 4     274589
# 5     238636
# 6     222462
# 7     140836
# 8     133378
# 9     106862
# 10    100681
# 11     86176
# 12     82956
# 13     79428
# 14     74484
# 15     64266
# 16     61964
# 17     58753
# 18     57928
# 19     56558
# 20     51281
# 21     47899
# 22     47248
# 23     46666
# 24     46329
# 25     44175
# 26     40245
# 27     37782
# 28     36119
# 29     33394
# 30     32510
# 31     29794
# 32     28492
# 33     27357
# 34     26122
# 35     25262
# 36     25202
# 37     25195
# 38     24654
# 39     24472
# 40     24244
# 41     24184
# 42     23124
# 43     22826
# 44     22719
# 45     21932
# 46     21901
# 47     21381
# 48     20398
# 49     20397

# %% [markdown]
# # Formatting

# %%
def _make_idx(df):
    res = df.apply(
        lambda row: str(row["sub_type"]) + row["pred"] + str(row["obj_type"]), axis=1
    )
    return res


combined_count = (
    triple_count_df.assign(idx=_make_idx)
    .rename(columns={"num_ents": "num_triple_ent"})
    .merge(
        literature_count_df.assign(idx=_make_idx)
        .rename(columns={"num_ents": "num_literature_ent"})
        .drop(columns=["sub_type", "pred", "obj_type"]),
        on=["idx"],
    )
    .drop(columns=["idx"])
)
combined_count
# Out:
#                     sub_type             pred                  obj_type  \
# 0               [aapp, gngm]   INTERACTS_WITH              [aapp, gngm]
# 1               [aapp, gngm]    COEXISTS_WITH              [aapp, gngm]
# 2               [aapp, gngm]  ASSOCIATED_WITH                    [dsyn]
# 3                     [dsyn]    COEXISTS_WITH                    [dsyn]
# 4                     [dsyn]           CAUSES                    [dsyn]
# 5               [orch, phsu]           TREATS                    [dsyn]
# 6               [aapp, gngm]   INTERACTS_WITH        [aapp, gngm, enzy]
# 7               [aapp, gngm]         PRODUCES              [aapp, gngm]
# 8         [aapp, gngm, enzy]   INTERACTS_WITH              [aapp, gngm]
# 9               [aapp, gngm]           CAUSES                    [dsyn]
# 10                    [phsu]           TREATS                    [dsyn]
# 11              [orch, phsu]   INTERACTS_WITH              [aapp, gngm]
# 12        [aapp, gngm, phsu]   INTERACTS_WITH              [aapp, gngm]
# 13              [aapp, gngm]   INTERACTS_WITH        [aapp, gngm, phsu]
# 14              [aapp, gngm]          AFFECTS                    [dsyn]
# 15              [aapp, gngm]   INTERACTS_WITH              [orch, phsu]
# 16        [aapp, gngm, enzy]    COEXISTS_WITH              [aapp, gngm]
# 17              [aapp, gngm]    COEXISTS_WITH        [aapp, gngm, enzy]
# 18        [aapp, gngm, phsu]    COEXISTS_WITH              [aapp, gngm]
# 19        [aapp, gngm, phsu]  ASSOCIATED_WITH                    [dsyn]
# 20                    [dsyn]          AFFECTS                    [dsyn]
# 21        [aapp, gngm, enzy]  ASSOCIATED_WITH                    [dsyn]
# 22              [aapp, gngm]    COEXISTS_WITH        [aapp, gngm, phsu]
# 23              [orch, phsu]   INTERACTS_WITH              [orch, phsu]
# 24        [aapp, gngm, phsu]           TREATS                    [dsyn]
# 25              [orch, phsu]    COEXISTS_WITH              [orch, phsu]
# 26                    [gngm]   INTERACTS_WITH              [aapp, gngm]
# 27              [orch, phsu]    COEXISTS_WITH              [aapp, gngm]
# 28              [orch, phsu]           CAUSES                    [dsyn]
# 29              [aapp, gngm]    COEXISTS_WITH              [orch, phsu]
# 30                    [orch]   INTERACTS_WITH              [aapp, gngm]
# 31              [aapp, gngm]   INTERACTS_WITH                    [phsu]
# 32              [orch, phsu]          AFFECTS                    [dsyn]
# 33              [aapp, gngm]   INTERACTS_WITH                    [orch]
# 34                    [phsu]   INTERACTS_WITH              [aapp, gngm]
# 35        [aapp, gngm, enzy]   INTERACTS_WITH        [aapp, gngm, enzy]
# 36              [aapp, gngm]   INTERACTS_WITH  [aapp, gngm, phsu, enzy]
# 37              [aapp, gngm]         PRODUCES        [aapp, gngm, phsu]
# 38              [orch, phsu]   INTERACTS_WITH        [aapp, gngm, enzy]
# 39  [aapp, gngm, phsu, enzy]   INTERACTS_WITH              [aapp, gngm]
# 40                    [phsu]   INTERACTS_WITH              [orch, phsu]
# 41              [orch, phsu]   INTERACTS_WITH                    [phsu]
# 42        [aapp, gngm, phsu]         PRODUCES              [aapp, gngm]
# 43              [aapp, gngm]   INTERACTS_WITH  [aapp, gngm, phsu, horm]
#
#     num_triple_ent  num_literature_ent
# 0           393759              673470
# 1           224098              332834
# 2           188961              423727
# 3           150166              385349
# 4            85231              222462
# 5            82263              274589
# 6            72194              140836
# 7            69691              106862
# 8            66742              133378
# 9            49178              100681
# 10           47416              238636
# 11           41085               64266
# 12           40310               79428
# 13           37926               74484
# 14           37243               57928
# 15           36017               56558
# 16           32877               46329
# 17           31103               44175
# 18           29459               51281
# 19           29425               86176
# 20           29167               58753
# 21           28862               61964
# 22           26038               47248
# 23           25150               40245
# 24           20354               82956
# 25           19721               32510
# 26           19634               21901
# 27           19208               24654
# 28           19064               46666
# 29           18400               22826
# 30           18381               25195
# 31           17063               37782
# 32           17038               25202
# 33           16904               24244
# 34           15535               33394
# 35           15067               47899
# 36           14439               29794
# 37           12706               26122
# 38           12525               21381
# 39           12172               24184
# 40           11710               28492
# 41           11644               27357
# 42           10388               22719
# 43            9912               23124

# %%
combined_count_select = (
    combined_count.assign(
        umls_ent_types=lambda df: df.apply(
            lambda s: set(s["sub_type"] + s["obj_type"]), axis=1
        )
    )
    .drop(columns=["sub_type", "obj_type"])
    .sort_values("num_triple_ent", ascending=False)
    .groupby(["pred"])
    .head(2)
    .reset_index(drop=True)
)
combined_count_select
# Out:
#                pred  num_triple_ent  num_literature_ent  \
# 0    INTERACTS_WITH          393759              673470
# 1     COEXISTS_WITH          224098              332834
# 2   ASSOCIATED_WITH          188961              423727
# 3     COEXISTS_WITH          150166              385349
# 4            CAUSES           85231              222462
# 5            TREATS           82263              274589
# 6    INTERACTS_WITH           72194              140836
# 7          PRODUCES           69691              106862
# 8            CAUSES           49178              100681
# 9            TREATS           47416              238636
# 10          AFFECTS           37243               57928
# 11  ASSOCIATED_WITH           29425               86176
# 12          AFFECTS           29167               58753
# 13         PRODUCES           12706               26122
#
#               umls_ent_types
# 0               {aapp, gngm}
# 1               {aapp, gngm}
# 2         {aapp, dsyn, gngm}
# 3                     {dsyn}
# 4                     {dsyn}
# 5         {phsu, dsyn, orch}
# 6         {aapp, enzy, gngm}
# 7               {aapp, gngm}
# 8         {aapp, dsyn, gngm}
# 9               {phsu, dsyn}
# 10        {aapp, dsyn, gngm}
# 11  {phsu, aapp, dsyn, gngm}
# 12                    {dsyn}
# 13        {phsu, aapp, gngm}

# %%
combined_triple_count_file = output_dir / "report-triple-count.csv"
combined_count_select.to_csv(combined_triple_count_file, index=False)
